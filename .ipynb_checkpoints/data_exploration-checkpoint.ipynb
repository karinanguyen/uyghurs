# %%
import pandas as pd
import random
import numpy as np
from pandas import read_csv
from matplotlib import pyplot
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sources= pd.read_csv('sources.csv') 
sources
# Out:
#            id         display_name                               url  \
# 0       69186  Afghan Online Press           http://www.aopnews.com/
# 1       59652      The Kabul Times  https://www.thekabultimes.gov.af
# 2       34027    Afghanistan Times    http://www.afghanistantimes.af
# 3      154955            Tolo News              https://tolonews.com
# 4      167540  Bakhtar News Agency            https://bakhtarnews.af
# ...       ...                  ...                               ...
# 11725  146589          Mbare Times            https://mbaretimes.com
# 11726  146589          Mbare Times            https://mbaretimes.com
# 11727  146589          Mbare Times            https://mbaretimes.com
# 11728  146589          Mbare Times            https://mbaretimes.com
# 11729  146589          Mbare Times            https://mbaretimes.com
#
#            country       month  baseline_count  uyghur_count
# 0      Afghanistan  2017-01-01               2             0
# 1      Afghanistan  2017-01-01               0             0
# 2      Afghanistan  2017-01-01               0             0
# 3      Afghanistan  2017-01-01               0             0
# 4      Afghanistan  2017-01-01               0             0
# ...            ...         ...             ...           ...
# 11725     Zimbabwe  2020-11-01             648             0
# 11726     Zimbabwe  2020-12-01             609             0
# 11727     Zimbabwe  2021-01-01             555             0
# 11728     Zimbabwe  2021-02-01            1058             1
# 11729     Zimbabwe  2021-03-01            1101             0
#
# [11730 rows x 7 columns]

# %%
#DATA EXPLORATION

# %%
#COUNTRIES' MENTIONS OVER TIME 
#Group by country, sum media mentions over time

# %%
sources['month'] = pd.to_datetime(sources['month'], format="%Y-%d-%m") 
sources['year']= sources['month'].dt.year
# Out:
#            id         display_name                               url  \
# 0       69186  Afghan Online Press           http://www.aopnews.com/
# 1       59652      The Kabul Times  https://www.thekabultimes.gov.af
# 2       34027    Afghanistan Times    http://www.afghanistantimes.af
# 3      154955            Tolo News              https://tolonews.com
# 4      167540  Bakhtar News Agency            https://bakhtarnews.af
# ...       ...                  ...                               ...
# 11725  146589          Mbare Times            https://mbaretimes.com
# 11726  146589          Mbare Times            https://mbaretimes.com
# 11727  146589          Mbare Times            https://mbaretimes.com
# 11728  146589          Mbare Times            https://mbaretimes.com
# 11729  146589          Mbare Times            https://mbaretimes.com
#
#            country      month  baseline_count  uyghur_count  year
# 0      Afghanistan 2017-01-01               2             0  2017
# 1      Afghanistan 2017-01-01               0             0  2017
# 2      Afghanistan 2017-01-01               0             0  2017
# 3      Afghanistan 2017-01-01               0             0  2017
# 4      Afghanistan 2017-01-01               0             0  2017
# ...            ...        ...             ...           ...   ...
# 11725     Zimbabwe 2020-01-11             648             0  2020
# 11726     Zimbabwe 2020-01-12             609             0  2020
# 11727     Zimbabwe 2021-01-01             555             0  2021
# 11728     Zimbabwe 2021-01-02            1058             1  2021
# 11729     Zimbabwe 2021-01-03            1101             0  2021
#
# [11730 rows x 8 columns]

# %%
country_overtime = sources.drop(columns=["id","display_name", "url", "month"])
country_overtime
# Out:
#            country  baseline_count  uyghur_count  year
# 0      Afghanistan               2             0  2017
# 1      Afghanistan               0             0  2017
# 2      Afghanistan               0             0  2017
# 3      Afghanistan               0             0  2017
# 4      Afghanistan               0             0  2017
# ...            ...             ...           ...   ...
# 11725     Zimbabwe             648             0  2020
# 11726     Zimbabwe             609             0  2020
# 11727     Zimbabwe             555             0  2021
# 11728     Zimbabwe            1058             1  2021
# 11729     Zimbabwe            1101             0  2021
#
# [11730 rows x 4 columns]

# %%
#country_overtime = country_overtime.groupby(["year", "country"]).sum()
#country_overtime

# %%
#country_overtime.plot(figsize=(20,40))
fig, ax = plt.subplots()
ax.set_xticks(country_overtime.year.unique())
country_overtime.groupby(["year", "country"]).sum()['uyghur_count'].unstack().plot(ax=ax)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-c93797bf35b6> in <module>
#       1 #country_overtime.plot(figsize=(20,40))
#       2 fig, ax = plt.subplots()
# ----> 3 ax.set_xticks(country_overtime.year.unique())
#       4 country_overtime.groupby(["year", "country"]).mean()['uyghur_count'].unstack().plot(ax=ax)
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5458             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5459                 return self[name]
# -> 5460             return object.__getattribute__(self, name)
#    5461
#    5462     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'year'
